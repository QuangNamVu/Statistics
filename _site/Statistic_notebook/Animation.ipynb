# %%
# %matplotlib inline
import os
FIG_PATH = os.getcwd() + "/../Statistic_Figures/"

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML, Image

# %%
rc('animation', html='html5')

# %%
# fig, ax = plt.subplots()

fig = plt.figure()
avg = []

# ax.set_xlim(( 0, 2))
# ax.set_ylim((-2, 2))

# line, = ax.plot([], [], lw=2)

# %%
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)
def clt(current):
    # if animation is at the last frame, stop it
    plt.cla()
    if current == 1000: 
        a.event_source.stop()

    plt.hist(avg[0:current])

    plt.gca().set_title('Expected value of die rolls')
    plt.gca().set_xlabel('Average from die roll')
    plt.gca().set_ylabel('Frequency')

    plt.annotate('Die roll = {}'.format(current), [3,27])

# %%
# call the animator. blit=True means only re-draw the parts that 
# have changed.
anim = animation.FuncAnimation(fig, clt,
#                                init_func=init,
                               frames=10000, interval=20, blit=True)
# Out:
# Traceback (most recent call last):
#   File "/home/nam/miniconda3/envs/torch/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/nam/miniconda3/envs/torch/lib/python3.6/site-packages/matplotlib/animation.py", line 953, in _start
#     self._init_draw()
#   File "/home/nam/miniconda3/envs/torch/lib/python3.6/site-packages/matplotlib/animation.py", line 1732, in _init_draw
#     self._draw_frame(next(self.new_frame_seq()))
#   File "/home/nam/miniconda3/envs/torch/lib/python3.6/site-packages/matplotlib/animation.py", line 1758, in _draw_frame
#     raise RuntimeError('The animation function must return a '
# RuntimeError: The animation function must return a sequence of Artist objects.

# %%
# 1000 simulations of die roll
n = 1000

# In each simulation, there is one trial more than the previous simulation
avg = []
for i in range(2,n):
    a = np.random.randint(1,7,i)
    avg.append(np.average(a))

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
anim.save(FIG_PATH + 'animation.gif', writer='imagemagick', fps=60)

# %%
a.save(FIG_PATH + 'central_limit_theorem.gif', writer='imagemagick', fps=10)
